# %% [markdown]
# ## <img src="https://bi64pro.com/wp-content/uploads/2020/07/bi64pro-black.png" width="100" height="100" /> Dataframes Fundamentals
# > Este notebook está desarrollado por el equipo de bi64pro

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) spark.createDataFrame()
#
# > Función que te permite crear dataframes

# %%
df=  [{'nombre': 'Raul', 'edad': 27 , 'ciudad': 'Lima' },
      {'nombre': 'Martin', 'edad': 30 , 'ciudad': 'Lima'},
      {'nombre': 'Christian', 'edad': 20 , 'ciudad': 'Trujillo'}]

dfCustomer=spark.createDataFrame(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/session.py:355: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn(&#34;inferring schema from dict is deprecated,&#34;
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) count()
#
# > Retorna el nro. de filas del dataset

# %%
dfCustomer.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: 3</div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) printSchema()
#
# > Función que que devuelve la estructura del dataframe

# %%
dfCustomer.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- ciudad: string (nullable = true)
# -- edad: long (nullable = true)
# -- nombre: string (nullable = true)
#
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) show(..)
#
# Esta función me permite visualizar los datos
#
# Parámetros opcionales:
# * **n**: Número de filas que queremos visualizar.
# * **truncate**: Si el valor es en True, las columnas de más de 20 caracteres serán omitidos

# %%
dfCustomer.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+------+
# ciudad|edad|nombre|
# +------+----+------+
#   Lima|  27|  Raul|
#   Lima|  30|Martin|
# +------+----+------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) display(..)
#
# Podemos utilizar tambien la función display para la visualización de datos y ver los datos de otra manera

# %%
display(dfCustomer)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ciudad</th><th>edad</th><th>nombre</th></tr></thead><tbody><tr><td>Lima</td><td>27</td><td>Raul</td></tr><tr><td>Lima</td><td>30</td><td>Martin</td></tr><tr><td>Trujillo</td><td>20</td><td>Christian</td></tr></tbody></table></div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) limit(..)
#
# La principal diferencia entre display y show , es que en show podemos indicarle el nro. de filas
#
# > Est función me permite crear un nuevo dataset donde le pueda colocar un límite de filas

# %%
dfCustomerLimit = dfCustomer.limit(2) 

dfCustomerLimit.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+------+
# ciudad|edad|nombre|
# +------+----+------+
#   Lima|  27|  Raul|
#   Lima|  30|Martin|
# +------+----+------+
#
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) select(..)
#
# Est función te permite seleccionr algunas columnas de un datfrme

# %%
dfCustomer.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- ciudad: string (nullable = true)
# -- edad: long (nullable = true)
# -- nombre: string (nullable = true)
#
# </div>

# %%
# Transform the data by selecting only three columns
dfCustomerSelect = (dfCustomer
  .select("nombre","edad") # Our 2nd transformation (4 >> 3 columns)
)
# Now let's take a look at what the schema looks like
dfCustomerSelect.printSchema()

dfCustomerSelect.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- nombre: string (nullable = true)
# -- edad: long (nullable = true)
#
# +---------+----+
#    nombre|edad|
# +---------+----+
#      Raul|  27|
#    Martin|  30|
# Christian|  20|
# +---------+----+
#
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) drop(..)
#
# La función drop() te permite eliminar columnas de un dataframe

# %%
dfCustomerDrop= dfCustomer.drop("edad")

dfCustomerDrop.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+---------+
#   ciudad|   nombre|
# +--------+---------+
#     Lima|     Raul|
#     Lima|   Martin|
# Trujillo|Christian|
# +--------+---------+
#
# </div>
